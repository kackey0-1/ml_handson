# %%
import warnings
warnings.simplefilter('ignore', F)

# %%
import os
import tarfile
import urllib.request
import pandas as pd

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
  os.makedirs(housing_path, exist_ok=True)
  tgz_path = os.path.join(housing_path, "housing.tgz")
  urllib.request.urlretrieve(housing_url, tgz_path)
  housing_tgz = tarfile.open(tgz_path)
  housing_tgz.extractall(path=housing_path)
  housing_tgz.close()


def load_housing_data(housing_path=HOUSING_PATH):
  csv_path = os.path.join(housing_path, "housing.csv")
  return pd.read_csv(csv_path)

# %%
fetch_housing()
df = load_housing_data()
display(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# check missing value.

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# drop missing value row

# %%
df = df.dropna()
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
display(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %% [markdown]
# process ocean_proximity by OrdinalEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_encoder = OrdinalEncoder()

df['ocean_proximity'] = ord_encoder.fit_transform(df[['ocean_proximity']])
display(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#        ocean_proximity
# 0                  3.0
# 1                  3.0
# 2                  3.0
# 3                  3.0
# 4                  3.0
# ...                ...
# 20635              1.0
# 20636              1.0
# 20637              1.0
# 20638              1.0
# 20639              1.0
#
# [20433 rows x 10 columns]

# %%
import numpy as np
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

y = df['median_house_value']
X = df.drop(columns=['median_house_value'])
print(y.shape)
print(X.shape)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# Out:
# (20433,)
# (20433, 9)

# %%
def get_eval(y_true, y_pred):
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  print('RMSE: {:.5f}'.format(rmse))

# %%
# kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} or callable, default=’rbf’
hyperparameter = {'kernel': 'linear', 'C': [1.0, 10.0, 100.0, 1000.0, 10000.0]}

for c in hyperparameter['C']:
  print('#####################################################')
  print("kernel: {}, C: {}".format(hyperparameter['kernel'], c))
  svr_kernel_model = SVR(kernel=hyperparameter['kernel'], C=c).fit(x_train, y_train)
  y_train_pred = svr_kernel_model.predict(x_train)
  y_test_pred = svr_kernel_model.predict(x_test)
  rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
  print(f"Evaluate SVR model(kernel={hyperparameter['kernel']}) with Training Datasets")
  get_eval(y_train, y_train_pred)
  print(f"Evaluate SVR model(kernel={hyperparameter['kernel']}) with Validation Datasets")
  get_eval(y_test, y_test_pred)
# Out:
# #####################################################
# kernel: linear, C: 1.0
# Evaluate SVR model(kernel=linear) with Training Datasets
# RMSE: 95327.32108
# Evaluate SVR model(kernel=linear) with Validation Datasets
# RMSE: 95918.14968
# #####################################################
# kernel: linear, C: 10.0
# Evaluate SVR model(kernel=linear) with Training Datasets
# RMSE: 74565.52878
# Evaluate SVR model(kernel=linear) with Validation Datasets
# RMSE: 74759.94896
# #####################################################
# kernel: linear, C: 100.0
# Evaluate SVR model(kernel=linear) with Training Datasets
# RMSE: 71288.91369
# Evaluate SVR model(kernel=linear) with Validation Datasets
# RMSE: 71197.02087
# #####################################################
# kernel: linear, C: 1000.0
# Evaluate SVR model(kernel=linear) with Training Datasets
# RMSE: 70890.51263
# Evaluate SVR model(kernel=linear) with Validation Datasets
# RMSE: 70600.54987
# #####################################################
# kernel: linear, C: 10000.0

# %%
from ctypes import c_buffer
hyperparameter = {'kernel': 'rbf', 'C': [1.0, 10.0, 100.0, 1000.0, 10000.0], 'gamma': ['scale', 'auto']}

for c in hyperparameter['C']:
  for gamma in hyperparameter['gamma']:
    print('#####################################################')
    print("kernel: {}, C: {}, gamma: {}".format(hyperparameter['kernel'], c, gamma))
    svr_kernel_model = SVR(kernel=hyperparameter['kernel'], C=c, gamma=gamma).fit(x_train, y_train)
    y_train_pred = svr_kernel_model.predict(x_train)
    y_test_pred = svr_kernel_model.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    print(f"Evaluate SVR model(kernel={hyperparameter['kernel']}, C={c_buffer}, gamma={gamma}) with Training Datasets")
    get_eval(y_train, y_train_pred)
    print(f"Evaluate SVR model(kernel={hyperparameter['kernel']}, C={c_buffer}, gamma={gamma}) with Validation Datasets")
    get_eval(y_test, y_test_pred)
